# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
data = []
for delta in range(3):
    data.append(np.array([4,7,5])+delta)

for datum in data:
#     ax.lines.remove(...)
#     plt.cla()
    plt.plot(datum)
    plt.pause(1)
# plt.show()

"""
C = plt.contourf(f1) 
for coll in C.collections: 
    plt.gca().collections.remove(coll) 
LineCollection.remove
clear
"""

"""
interactive mode: `plt.cla`, `pause`, `show`, `fig.canvas.mpl_connect`, \
    `interact`, `observe`, `ax.clear`, `mpl.widgets`
inline mode: `cla`, `interact(fig in listener)`, `observe(fig in listener)`, \
    `ax.clear`
"""
# Out:
# '\ninteractive mode: `cla`, `pause`, `show`, `fig.canvas.mpl_connect`\ninline mode: `cla`\n'

# %%
# %matplotlib inline
from matplotlib.patches import ConnectionPatch
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 3))

xyA = (0.2, 0.2)
xyB = (0.8, 0.8)
coordsA = "data"
coordsB = "data"
con = ConnectionPatch(xyA, xyB, coordsA, coordsB,
                      arrowstyle="-|>", shrinkA=5, shrinkB=5,
                      mutation_scale=20, fc="w")
ax1.plot([xyA[0], xyB[0]], [xyA[1], xyB[1]], "o")
ax1.add_artist(con)

xy = (0.3, 0.2)
coordsA = "data"
coordsB = "data"
con = ConnectionPatch(xyA=xy, xyB=xy, coordsA=coordsA, coordsB=coordsB,
                      axesA=ax2, axesB=ax1,
                      arrowstyle="<-", shrinkB=1,
                      connectionstyle='bar',
                      mutation_scale=10, )
ax2.add_artist(con)
print(dir(con))
from dill.source import getsource
# print(getsource(con.set_aa))
print(con.xy1)
print(con.xy2)
con.xy2=(0.5,0.5)

ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)
ax2.set_xlim(0, .5)
ax2.set_ylim(0, .5)

plt.show()
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_agg_filter', '_alpha', '_animated', '_annotation_clip', '_antialiased', '_arrow_transmuter', '_axes', '_capstyle', '_check_xy', '_clipon', '_clippath', '_combined_transform', '_connector', '_contains', '_dashes', '_dashoffset', '_dpi_cor', '_edge_default', '_edgecolor', '_facecolor', '_fill', '_get_xy', '_gid', '_hatch', '_hatch_color', '_joinstyle', '_label', '_linestyle', '_linewidth', '_mouseover', '_mutation_aspect', '_mutation_scale', '_oid', '_original_edgecolor', '_original_facecolor', '_path_effects', '_path_original', '_picker', '_posA_posB', '_process_radius', '_prop_order', '_propobservers', '_rasterized', '_remove_method', '_set_edgecol
# ...

# %%
import matplotlib as mpl
print(mpl.__version__)
# Out:
# 2.1.0
