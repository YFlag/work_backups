# %%
import matplotlib as mpl
print(mpl.get_backend())
print(mpl.is_interactive())
# Out:
# module://ipykernel.pylab.backend_inline
# False

# %%
# %matplotlib inline
import matplotlib as mpl
print(mpl.get_backend())
print(mpl.is_interactive())
# Out:
# module://ipykernel.pylab.backend_inline
# True

# %%
# %matplotlib notebook
import matplotlib as mpl
print(mpl.get_backend())
print(mpl.is_interactive())
# Out:
# nbAgg
# True

# %%
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(1)

x = np.random.rand(15)
y = np.random.rand(15)
names = np.array(list("ABCDEFGHIJKLMNO"))
c = np.random.randint(1,5,size=15)

norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(x,y,c=c, s=100, cmap=cmap, norm=norm)

annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
annot.set_visible(False)

def update_annot(ind):
    pos = sc.get_offsets()[ind["ind"][0]]
    print(sc.get_offset_position())
    annot.xy = pos
    text = "{}, {}".format(" ".join(list(map(str,ind["ind"]))),
                           " ".join([names[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor(cmap(norm(c[ind["ind"][0]])))
    annot.get_bbox_patch().set_alpha(0.4)


def hover(event):
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
#             ax.plot([1,4,3])
            update_annot(ind)
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(1)

x = np.random.rand(15)
y = np.random.rand(15)
names = np.array(list("ABCDEFGHIJKLMNO"))
c = np.random.randint(1,5,size=15)

norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(x,y,c=c, s=100, cmap=cmap, norm=norm)

def hover(event):
    print(1)
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        display(cont, ind)
#         fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 7

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
l = ax.plot([1,5,2], linewidth=10)

def hover(event):
#     vis = annot.get_visible()
    print('1')
    if event.inaxes == ax:
        cont, ind = l.contains(event)
        print(cont, ind)
#         fig.canvas.draw_idle()
#         if cont:
#             update_annot(ind)
#             annot.set_visible(True)
#             fig.canvas.draw_idle()
#         else:
#             if vis:
#                 annot.set_visible(False)
#                 fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import feature_visualization as fv

fv.reset()
fig, axes = plt.subplots(2,1,figsize=(4,8),sharex=True,sharey=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="288">
