# %%
# %matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt
import ipywidgets as widgets
import numpy as np
import pdb
fig, ax = plt.subplots()
# fig = plt.Figure()
# ax = fig.add_subplot(111)
def do_plot():
    global initial
    if initial:
        global a, l, fig, ax
        
        l, = ax.plot([1,2,5])
        ax.set_xlim(0,3)
        initial = False
    else:
        pass
#         l.set_data(range(3), np.array([1,2,5])+a)
    plt.show()

def update(x):
    global a
    a = x
    do_plot()
    l.set_data(range(3), np.array([1,2,5])+a)
    
initial = True
widgets.interact(update, x=(0,1,0.1,))
aa = 3
# pdb.set_trace()
xxx = 1
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=0.0, description='x', max=1.0), Output()), _dom_classes=('widget-inter…

# %%
print(l.get_data())
print(a, fig, ax, l)

print(mpl.is_interactive())
print(mpl.get_backend())
# Out:
# (range(0, 3), array([ 1.4,  2.4,  5.4]))
# 0.4 Figure(800x600) AxesSubplot(0.125,0.11;0.775x0.77) Line2D(_line0)
# True
# nbAgg
